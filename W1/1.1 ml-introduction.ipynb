# %% [markdown]
# #### Different ML algorithms:
# >- Liner Regression
# >- Logistic Regression
# >- Decision Trees
# >- Support Vector Machine (SVM)
# >- Neural Networks
# >- K-means clustering

# %% [markdown]
# #### ML components:
# >1. Training Data
# >2. Model Building
# >3. Loss Function
# >4. Optimization Technique
# >5. Evaluation
